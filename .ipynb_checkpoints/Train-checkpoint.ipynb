# %%
import tensorflow as tf
import keras 
from tensorflow.keras import models , layers 
import matplotlib.pyplot as plt

# %%
IMG_SZE=256
BATCH_SZE=32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "dataset",
    shuffle=True,
    image_size=(IMG_SZE,IMG_SZE),
    batch_size=BATCH_SZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
for image ,label in dataset.take(1):
    print(image.shape)
    print(label.numpy())
# Out:
# (32, 256, 256, 3)
# [0 1 1 0 1 1 0 1 1 1 1 0 0 1 2 0 0 0 0 0 2 0 2 0 0 0 0 0 0 0 0 1]

# %% [markdown]
# ### SPLIT DA DATA

# %%
train_ds = dataset.take(round(len(dataset)*0.8))
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(round(len(dataset)*0.2))
len(test_ds)
# Out:
# 14

# %%
def get_patrion(ds,train_split= 0.8,val_split = 0.1 , test_split = 0.1 , shuffle=True, shuffle_size = 10000):
    ds_size = len(ds)
    if shuffle :
        ds=ds.shuffle(shuffle_size,seed=43)
    train_size = round(len(dataset)*train_split)
    test_size = round(len(dataset)*test_split)
    val_size = round(len(dataset)*val_split)
                     
    train_ds = dataset.take(train_size)
    val_ds = dataset.skip(train_size).take(val_size)
    test_ds = dataset.skip(train_size).skip(val_size)
    return train_ds,val_ds,test_ds

# %%
train,val,test = get_patrion(dataset)

# %%
train = train.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val = val.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test = test.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_scalling = tf.keras.Sequential([
    keras.layers.experimental.preprocessing.Resizing(IMG_SZE,IMG_SZE),
    keras.layers.experimental.preprocessing.Rescaling(1.0/255)
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 resize_and_scalling = tf.keras.Sequential([
# ----> 2     keras.layers.experimental.preprocessing.Resizing(IMG_SZE,IMG_SZE),
#       3     keras.layers.experimental.preprocessing.Rescaling(1.0/255)
#       4 ])
#
# AttributeError: module 'keras.api.layers' has no attribute 'experimental'
